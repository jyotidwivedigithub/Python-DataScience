# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
from urllib.request import urlopen
import logging

# %%
flipcart_url = "https://www.flipkart.com/search?q=" + "iphone14plus"     # Search product url

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone14plus'

# %%
urlclient = urlopen(flipcart_url)   # we can also use uReq(flipcart_url)
                                    # Automatic open url

# %%
urlclient

# %%
flipcart_page = urlclient.read()      # Read all information present in url page

# %%
flipcart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.d4bb4f.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flipcart_html = bs(flipcart_page, 'html.parser')    # Beutify the data using BeautifulSoup

# %%
flipcart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
"https://www.flipkart.com"+"/apple-iphone-14-plus-blue-128-gb/p/itmac8385391b02b?pid=MOBGHWFHUYWGB5F2&amp;lid=LSTMOBGHWFHUYWGB5F2RJNHBM&amp;marketplace=FLIPKART&amp;q=iphone14plus&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=99f42c90-da86-480b-b5f9-1269e3a328cb.MOBGHWFHUYWGB5F2.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=zzrnzr2d1s0000001695404153306&amp;qH=0c4b2d2b13e2dee3"
    
# Get product url(href) manually
# Out:
# 'https://www.flipkart.com/apple-iphone-14-plus-blue-128-gb/p/itmac8385391b02b?pid=MOBGHWFHUYWGB5F2&amp;lid=LSTMOBGHWFHUYWGB5F2RJNHBM&amp;marketplace=FLIPKART&amp;q=iphone14plus&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=99f42c90-da86-480b-b5f9-1269e3a328cb.MOBGHWFHUYWGB5F2.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=zzrnzr2d1s0000001695404153306&amp;qH=0c4b2d2b13e2dee3'

# %%
bigbox = flipcart_html.findAll("div", {"class":"_1AtVbE col-12-12"})  # find div tag ("div", {"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 30

# %%
bigbox[1]
# Out:
# <div class="_1AtVbE col-12-12"><a class="_1nY1tt" href="/buying-guide/mobiles?sid=tyy,4io&amp;otracker=bg_from_browse_lhs" title="Buying Guide"><div><span>Need help?</span></div><div class="_1mVNvF"><span>Help me decide</span><svg class="ViewtL" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="_2Zt1Py" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><img alt="Buying Guide" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/buying-guide-illustration_4dd325.png"/></a></div>

# %%
bigbox[3]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBGHWFHYFJWRHAG" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-14-plus-purple-128-gb/p/itm7a759a472d863?pid=MOBGHWFHYFJWRHAG&amp;lid=LSTMOBGHWFHYFJWRHAGX1JLRZ&amp;marketplace=FLIPKART&amp;q=iphone14plus&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=search&amp;fm=organic&amp;iid=0c6f95bc-3c11-43a3-83e5-7914a4ca747f.MOBGHWFHYFJWRHAG.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=udxgmm9q9s0000001695541770112&amp;qH=0c4b2d2b13e2dee3" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 14 Plus (Purple, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/v/0/t/-original-imaghxa5rgcv5enm.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly=
# ...

# %%
del bigbox[0:3]                # Remove extra layer

# %%
bigbox[3].div
# Out:
# <div class="_13oc-S"><div data-id="MOBGHWFH7QBPGBKT" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-14-plus-blue-256-gb/p/itm78e5012107786?pid=MOBGHWFH7QBPGBKT&amp;lid=LSTMOBGHWFH7QBPGBKTHVMRAH&amp;marketplace=FLIPKART&amp;q=iphone14plus&amp;store=tyy%2F4io&amp;srno=s_1_5&amp;otracker=search&amp;fm=organic&amp;iid=0c6f95bc-3c11-43a3-83e5-7914a4ca747f.MOBGHWFH7QBPGBKT.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=udxgmm9q9s0000001695541770112&amp;qH=0c4b2d2b13e2dee3" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone
://www.flipkart.com"+bigbox[3].div.div.div.a['href']

# %%
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-14-plus-yellow-128-gb/p/itme660a4bfe5de6?pid=MOBGNHT7DSWFGNRJ&lid=LSTMOBGNHT7DSWFGNRJFCNDHY&marketplace=FLIPKART&q=iphone14plus&store=tyy%2F4io&srno=s_1_8&otracker=search&fm=organic&iid=0c6f95bc-3c11-43a3-83e5-7914a4ca747f.MOBGNHT7DSWFGNRJ.SEARCH&ppt=None&ppn=None&ssid=udxgmm9q9s0000001695541770112&qH=0c4b2d2b13e2dee3'

# %%
product_req = requests.get(productlink)    # Get productlink one by one

# %%
product_req
# Out:
# <Response [200]>

# %%
product_html = bs(product_req.text, 'html.parser')

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
comment_box = product_html.find_all("div",{"class" : "_16PBlm"})   # find product review link

# %%
comment_box
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Terrific</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Nice phone with great camera. My 1st iPhone and I m loving it</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_9740b36e982041658cafa8554ec2d614.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_62bd5e6a58444b18a1d708b9bc4d8193.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_71a271b6fec745f38
# ...

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[0].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})    # find customer name
# Out:
# [<p class="_2sc7ZR _2V5EHH">Priteshkumar Rana</p>]

# %%
for i in comment_box:                              # find all customer name
    print(i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Priteshkumar Rana
# TAPAL SADDAM
# Nagorao Ghagare
# Faiz Khan
# Jatin Marwal
# subham kumar Kachhap
# Aniket Ashtekar
# SATYADEV SAHU
# Selim Choudhury
# Sudip Karan
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 2
#       1 for i in comment_box:                              # find all customer name
# ----> 2     print(i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.div.text      # find rating
# Out:
# '5'

# %%
for i in comment_box:                   # find all rating
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 5
# 4
# 5
# 5
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 2
#       1 for i in comment_box:                   # find all rating
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div
# Out:
# <div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Terrific</p></div>

# %%
comment_box[0].div.div.div.p.text     # find comment
# Out:
# 'Terrific'

# %%
for i in comment_box:                # find all comment
    print(i.div.div.div.p.text)
# Out:
# Terrific
# Brilliant
# Brilliant
# Perfect product!
# Wonderful
# Simply awesome
# Wonderful
# Fabulous!
# Brilliant
# Excellent
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 2
#       1 for i in comment_box:                # find all comment
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.find_all('div',{"class":''})
# Out:
# [<div><div class="">Nice phone with great camera. My 1st iPhone and I m loving it</div><span class="_1H-bmy"><span>READ MORE</span></span></div>,
#  <div class="">Nice phone with great camera. My 1st iPhone and I m loving it</div>,
#  <div></div>]

# %%
comment_box[0].div.div.find_all('div',{"class":''})[0]

# %%
comment_box[0].div.div.find_all('div',{"class":''})[0].div.text  # get actuall comment
# Out:
# 'Nice phone with great camera. My 1st iPhone and I m loving it'

# %%
for i in comment_box:                        # get all comment
    print(i.div.div.find_all('div',{"class":''})[0].div.text)
# Out:
# Nice phone with great camera. My 1st iPhone and I m loving it
# Super phone . camera is super😍
# SUPERBGo for it guys without hesitation, great in hand feel ,, superb camera , awesome battery backup , Starlight Colour looks premium, 6.7 inch crisp display, Camera 5/5 performance 5/5 Very happy to have apple 14 plus,Thanks flipcart for genuine product delivered on time
# Its good phone, value for the money.
# Awesome camera quality
# Just wow I cannot express my feelings ❤️😍
# I think the iPhone 14 Plus is the king of Battery Life.  iPhone 14 Plus Camera is also very good. All rounder iPhone in every department..
# Great PerformanceCamera better than iPhone 13Battery backup also goodIphone 14 plus is just awesome.
# I love the pictures and the night mode was awesome.... Mind-blowing product..
# Superb.... must purchase ! first time switched from android but not feel such an issue working fine as all options avilable here ,Camera is best and Battary is huge.
# ...
